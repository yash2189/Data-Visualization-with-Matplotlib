# %% [markdown]
# # VISUALIZING THE DATA OF COUNTRIES

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\yasha\Downloads\2019.csv')
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
# Overall rank                    156 non-null int64
# Country or region               156 non-null object
# Score                           156 non-null float64
# GDP per capita                  156 non-null float64
# Social support                  156 non-null float64
# Healthy life expectancy         156 non-null float64
# Freedom to make life choices    156 non-null float64
# Generosity                      156 non-null float64
# Perceptions of corruption       156 non-null float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.0+ KB

# %%
sns.distplot(df['GDP per capita'])

# %%
sns.distplot(df['GDP per capita'], kde = False , bins = 30)

# %%
plt.scatter(df['GDP per capita'],df['Healthy life expectancy'])
plt.xlabel('GDP per capita')
plt.ylabel('Healthy life expectancy')
plt.show()

# %%
sns.barplot(x=df['Country or region'].head(3),y=df['GDP per capita'],data=df)

# %%
# Matrix form for correlation data
data_select = df[['GDP per capita','Social support','Healthy life expectancy','Perceptions of corruption']]
data_select.corr()
# Out:
#                            GDP per capita  Social support  \
# GDP per capita                   1.000000        0.754906
# Social support                   0.754906        1.000000
# Healthy life expectancy          0.835462        0.719009
# Perceptions of corruption        0.298920        0.181899
#
#                            Healthy life expectancy  Perceptions of corruption
# GDP per capita                            0.835462                   0.298920
# Social support                            0.719009                   0.181899
# Healthy life expectancy                   1.000000                   0.295283
# Perceptions of corruption                 0.295283                   1.000000

# %%
sns.heatmap(data_select.corr(), cmap='coolwarm')

# %%
sns.jointplot(x=df['GDP per capita'], y= df['Healthy life expectancy'],data=df)# two ditribution

# %%
sns.jointplot(x=df['GDP per capita'], y= df['Healthy life expectancy'],data=df,kind='reg')# linear regression

# %%
sns.jointplot(x=df['GDP per capita'], y= df['Healthy life expectancy'],data=df,kind='hex')

# %%
# Just the Grid
sns.PairGrid(data_select)

# %%
#MAP TO GRID
g = sns.PairGrid(data_select)
g.map(plt.scatter)
